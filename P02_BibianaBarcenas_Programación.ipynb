# %% [markdown]
# # Hola chicos.
#
# ## Esta es la pŕactica #2.-Operadores de aritméticos y de asignación (10 pts.).
#
# Ejemplo en la suma:
# --Sumar dos variables llamadas a y b
#
# a=10
#
# b=11
#
# c=a+b
#
# print("La suma de a + b es igual a: ", c)
#
# ### Resuleve los siguientes ejercicios:

# %%
# Ejemplo en la suma: --Sumar dos variables llamdas a y b--

a=10
b=11
c=a+b
print("La suma de a + b es igual a: ", c)
# Out:
# La suma de a + b es igual a:  21

# %% [markdown]
# # Se tienen las variables a, b y c y se desea calcular las siguientes operaciones aritméticas (5 pts.):
# ![Captura de pantalla de 2023-02-22 19-38-23.png](data:image/png;base64,...)

# %% [markdown]
# # Además, se desea calcular las siguientes expresiones con operadores de asignación (5 pts.).
#
# ## Ejemplo:
#
# x = 5
#
# x += 3
#
# print(x)
#
# ![Captura de pantalla de 2023-02-22 19-50-40.png](data:image/png;base64,...)

# %%
# Ejemplo con operadores de asignación:

x = 5

x += 3

print(x)
# Out:
# 8

# %%
float=4.5
print(float)
# Out:
# 4.5
